# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import importlib
import pandas as pd
import re
import scipy.special 
import scipy.interpolate as interp
from scipy.integrate  import nquad
from scipy.integrate  import dblquad

import sys
from time import process_time as time
sys.path.append('../')

try:
    importlib.reload(star_props.helium_flash)
except NameError:
    import star_props.helium_flash
except Exception as e:
    print("Unexpected error during reload")
    print(e)
    
    
    
    
    
from scipy.interpolate import NearestNDInterpolator
from star_props.helium_flash import HeliumDeflagration as deflag
from star_props.helium_flash import HeliumFlash 
from star_props.helium_flash import Star
from star_props.helium_flash import DarkMatter 


from mpl_toolkits.axes_grid1 import make_axes_locatable

matplotlib.rcParams['figure.figsize'] = [20.0, 15.0]
matplotlib.rcParams.update({'font.size': 22})


Rsol2cm = 6.957e10
Msol2g = 1.989e33
gev2g = 1.7826619e-24
GN = 6.674e-8
rsol=6.957e10 #solar radius in cm
c = 2.9979e10
s2Gyr=1/(3.1536e16)

# %%
def get_ZA4(file):
    z2_data = np.loadtxt(file,delimiter=' ',dtype=str)
    el_z2_data = [ [int(re.sub('[^0-9]','',el[0])),float(el[1]) ] for el in z2_data]
    return sum( Z*A**4 for A,Z in el_z2_data )

print(get_ZA4('../data/metal_z_-2.txt'))
print(get_ZA4('../data/metal_z_-1.txt'))
print(get_ZA4('../data/metal_z_0.txt'))
print(get_ZA4('../data/metal_z_0.txt')/get_ZA4('../data/metal_z_-1.txt'))
# Out:
# 153.44847531700762
# 773.4225450481082
# 16450.034601336618
# 21.269142859435778

# %%
folder="/home/zajohns/dm-helium-flash/data/0.790_solar_mass/"
N_arrays=5

data=[]
for i in range(0,N_arrays):
    data_piece= list(np.load(folder+"flash_scan-{0}.npy".format(i),
            allow_pickle=True,encoding='latin1'))
    data+=data_piece
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-84d657a7eaf3> in <module>
#       3 for i in range(0,10):
#       4     data_piece= list(np.load(folder+"flash_scan-{0}.npy".format(i),
# ----> 5             allow_pickle=True,encoding='latin1'))
#       6     data+=data_piece
#
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     420         own_fid = False
#     421     else:
# --> 422         fid = open(os_fspath(file), "rb")
#     423         own_fid = True
#     424
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/zajohns/dm-helium-flash/data/0.790_solar_mass/flash_scan-5.npy'

# %%
v_values=set([dat[0][4] for dat in data])
m_values=set([dat[0][1] for dat in data])
b_values=set([dat[0][0] for dat in data])
sig_values=set([dat[0][3] for dat in data])
t_values=set([dat[0][2] for dat in data])

N_v = len(v_values)
N_m = len(m_values)
N_b = len(b_values)
N_sig = len(sig_values)
N_t = len(t_values)

m_list=np.sort(list(m_values));
sig_list=np.sort(list(sig_values))#/24;
t_list=np.sort(list(t_values));
b_list=np.sort(list(b_values));
v_list=np.sort(list(v_values));

print(b_list)
# Out:
# [9.10e+06 2.34e+07 6.04e+07 1.56e+08 4.01e+08 1.03e+09 2.66e+09 6.86e+09
#  1.77e+10 4.55e+10]

# %% [markdown]
# The output is in the form
#
# $(b,\ m,\ age,\ \sigma,\ v )$, (hit_core, ignited)

# %%
#shaped_data = [[dat[0][0:5],dat[1][1]] for dat in data]
reversed_data = np.array(data).reshape(( N_v,N_sig, N_t, N_m, N_b, 2))
#reversed_data = np.array(data).reshape((N_b,N_m,N_t,N_sig,N_v, 2))

print(reversed_data[5,5,5,5,5])
print(reversed_data[5,5,5,6,5])
print()
print(reversed_data[5,3,5,5,5])
print(reversed_data[5,5,5,5,5])
# Out:
# [array([1.03e+09, 2.07e+19, 4.61e+09, 4.28e+02, 1.77e-03]) (True, True)]
# [array([1.03e+09, 3.79e+19, 4.61e+09, 4.28e+02, 1.77e-03]) (True, True)]
#
# [array([1.03e+09, 2.07e+19, 4.61e+09, 3.79e+01, 1.77e-03]) (True, False)]
# [array([1.03e+09, 2.07e+19, 4.61e+09, 4.28e+02, 1.77e-03]) (True, True)]

# %% [markdown]
# The output is now in the form
#
# $(v, \sigma, \ age, \ m, \ b)$, (hit_core, ignited)

# %%
rhoDM=0.4*gev2g #g/cm^3
cm = plt.cm.get_cmap('RdYlBu')
v0=7.33e-4 ; vesc=2.0e-3  # v0=220 km/s, vesc=500-600 km/s
vstar = np.array([0,0,0])*2e7/c


Norm = lambda v0: np.pi**1.5*v0**3*( scipy.special.erf(vesc/v0)-
                                        (2/np.sqrt(np.pi))*(vesc/v0)*np.exp(-vesc**2/v0**2) ) 

def f_vDM(vx,vy,vz):
    #return np.exp(-v**2/v0**2)*np.heaviside(vesc-v,0.5)/Norm(v0)
    vxrel=vx-vstar[0];
    vyrel=vy-vstar[1];
    vzrel=vz-vstar[2];
    vrel=np.sqrt((vxrel**2 + vyrel**2 + vzrel**2))
    dist= np.exp(-vrel**2/v0**2)*np.heaviside(vesc-vrel,0)
    return dist/Norm(v0)
def f_vDM(v):
    dist= 4*np.pi*v**2*np.exp(-v**2/v0**2)*np.heaviside(vesc-v,0)
    return dist/Norm(v0)
#Norm=nquad(f_vDM, [[  -vesc,vesc],[-vesc,vesc],[  -vesc,vesc] ] ,opts={'epsabs':0,'epsrel':1e-2}
#Norm=nquad(f_vDM, [[  0,vesc]] ,opts={'epsabs':0,'epsrel':1e-2})
#print(Norm)
print(f_vDM(1e-3))
# Out:
# 892.6843204773714

# %%
#@np.vectorize

def my_round(f):
    def f_wrapped(*args,**kwargs):
        return np.around(f(*args,**kwargs),0)
    return f_wrapped


def get_flash_r(mi,sigi,ti):
    piece=reversed_data[:,sigi,ti,mi,:]
    _, m, t, sig,_ = piece[0,0,0]
    did_flash= [[ int(piece[:,:,1][vi,bi][1])  for bi in range(len(b_list))] for vi in range(len(v_list))]
    bs = [cons_v_piece[0] for cons_v_piece in piece[0,:][:,0]]
    vs = [cons_b[4] for cons_b in piece[:,0][:,0] ]
    
    #     def integrand(vx,vy,vz,b):
    #         vrel = np.sqrt(vx**2 + vy**2 + vz**2)
    #         pflash_interp = my_round(interp.interp2d(bs,vs, did_flash,fill_value=None)) #takes (b,v)
    #         dPhidb= lambda vin, b: (2*np.pi)*(rhoDM/m)*b*(vin*c)
    #         #print(dPhidb(vrel,b),pflash_interp(b,vrel),f_vDM(vx,vy,vz))
    #         return dPhidb(vrel,b)*pflash_interp(b,vrel)*f_vDM(v)/(s2Gyr)
    
    def integrand(v,b):
        pflash_interp = my_round(interp.interp2d(bs,vs, did_flash,fill_value=None)) #takes (b,v)
        dPhidb= lambda vin, b: (2*np.pi)*(rhoDM/m)*b*(vin*c)
        #print(v,b)
        
        return dPhidb(v,b)*pflash_interp(b,v)*f_vDM(v)/(s2Gyr)
    
    #print(integrand(v0/5,0,0,b_list[-3]) )
    #return nquad(integrand, [[  0,vesc], [ 0,max(b_list)]],opts={'epsrel':1e-2,'epsabs':1e-12,'limit':5}) 
    rate, error = dblquad(integrand,0,max(b_list), 0,vesc,epsrel=1e-1,epsabs=1e-5) 
    #print(rate,error)
    return rate



def get_flash_rate(mi,sigi,ti,vi):
    piece=reversed_data[vi,sigi,ti,mi,:]
    _, m, t, sig,v = piece[0,0]
    bs=[p[0] for p in piece[:,0]]
    did_flash = [p[1] for p in piece[:,1]]
    db1 = np.array(b_list) - np.array(([0]+list(b_list[:-1])))
    dPhidb=db1*2*(rhoDM/m)*np.pi*np.array(b_list)*v*c
    return sum(dPhidb*did_flash)/(s2Gyr)

get_flash_r(5,5,5)
# Out:
# 10.62256502503214

# %%
White_Dwarf_bounds=[[8.96e+10, 7.66e-8],[7.77e+20, 7.36e-8],[4.55e+22, 1.32e+2],
[4.55e+22, 1.00e+7],[9.63e+17, 1.22e+2],[9.70e+19, 2.05e+4]]#From 1912.04053

# %%
star.agedata[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ef33a2165b54> in <module>
# ----> 1 star.agedata[-1]
#
# NameError: name 'star' is not defined

# %%
t_Flash=4.67370354266633e9
flash_rates=[]
for ti in range(len(t_list)):
    print('\n',ti,'/',len(t_list),end='')
    flash_rates.append([[  np.log10(   1e-9*get_flash_r(m,sig,ti)*(t_Flash - t_list[ti])  )
             for m in range(len(m_list))] for sig in range(len(m_list))])
np.save("../data/1.3_solar_mass/flash_rates-linear.npy",flash_rates)
# Out:
#  0 / 10
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log10
#  1 / 10
#  2 / 10
#  3 / 10
#  4 / 10
#  5 / 10
#  6 / 10
#  7 / 10
#  8 / 10
#  9 / 10
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-2ebf71dfeb88> in <module>
#       6              for m in range(len(m_list))] for sig in range(len(m_list))])
#       7
# ----> 8 np.save("~/dm-helium-flash/data/1.3_solar_mass/flash_rates-linear.npy",flash_rates)
#
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     522         if not file.endswith('.npy'):
#     523             file = file + '.npy'
# --> 524         fid = open(file, "wb")
#     525         own_fid = True
#     526
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/dm-helium-flash/data/1.3_solar_mass/flash_rates-linear.npy'

# %%
np.save("../data/1.3_solar_mass/flash_rates-linear.npy",flash_rates)

# %%
#ti=0
#vi=-2
M,Sig= np.meshgrid(m_list,sig_list);
for ti in range(0,len(t_values)):
    fig, ax = plt.subplots();


    Flash=flash_rates[ti]
    sc = ax.scatter(M,Sig,c=Flash,cmap=cm,vmin=-1,vmax=1)
    cbar=plt.colorbar(sc)
    cbar.ax.set_ylabel(r'$log_10(#Flashes Expected)$', rotation=270)


    ax.add_patch(matplotlib.patches.Polygon(White_Dwarf_bounds,closed=True,alpha=0.2))

    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_ylim(1e-8,1e10)
    ax.set_xlim(1e10,1e23)
    ax.set_ylabel(r'$\sigma [cm^2]$')
    ax.set_xlabel(r'$m [g]$')
    ax.set_title(r"Rough # Flashed @ $t_{remaining}$" + 
                 r" = {0} Myr".format(np.round((t_Flash-t_list[ti])/1e6,0)))

# %%
t_Flash=4.67370354266633e9

for vi in range(0,len(v_values)):
    fig, ax = plt.subplots();
    M,Sig= np.meshgrid(m_list,sig_list);
    Flash= [[  np.log10(   1e-9*get_flash_r(m,sig,ti)*(t_Flash - t_list[ti])  )
             for m in range(len(m_list))] for sig in range(len(m_list))];

    sc = ax.scatter(M,Sig,c=Flash,cmap=cm,vmin=-1,vmax=1)
    cbar=plt.colorbar(sc)
    cbar.ax.set_ylabel(r'$log_10(#Flashes Expected)$', rotation=270)


    ax.add_patch(matplotlib.patches.Polygon(White_Dwarf_bounds,closed=True,alpha=0.2))

    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_ylim(1e-8,1e10)
    ax.set_xlim(1e10,1e23)
    ax.set_ylabel(r'$\sigma [cm^2]$')
    ax.set_xlabel(r'$m [g]$')
    ax.set_title(r"Rough # Flashed @ $t_{remaining}$" + 
                 r" = {0} Myr, v = {1}".format(np.round((t_Flash-t_list[ti])/1e6,0)))
# Out:
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log10
#   import sys
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-8d9d01f04934> in <module>
#       5     M,Sig= np.meshgrid(m_list,sig_list);
#       6     Flash= [[  np.log10(   1e-9*get_flash_r(m,sig,ti)*(t_Flash - t_list[ti])  )
# ----> 7              for m in range(len(m_list))] for sig in range(len(m_list))];
#       8
#       9     sc = ax.scatter(M,Sig,c=Flash,cmap=cm,vmin=-1,vmax=1)
#
# <ipython-input-25-8d9d01f04934> in <listcomp>(.0)
#       5     M,Sig= np.meshgrid(m_list,sig_list);
#       6     Flash= [[  np.log10(   1e-9*get_flash_r(m,sig,ti)*(t_Flash - t_list[ti])  )
# ----> 7              for m in range(len(m_list))] for sig in range(len(m_list))];
#       8
#       9     sc = ax.scatter(M,Sig,c=Flash,cmap=cm,vmin=-1,vmax=1)
#
# <ipython-input-25-8d9d01f04934> in <listcomp>(.0)
#       5     M,Sig= np.meshgrid(m_list,sig_list);
#       6     Flash= [[  np.log10(   1e-9*get_flash_r(m,sig,ti)*(t_Flash - t_list[ti])  )
# ----> 7              for m in range(len(m_list))] for sig in range(len(m_list))];
#       8
#       9     sc = ax.scatter(M,Sig,c=Flash,cmap=cm,vmin=-1,vmax=1)
#
# <ipython-input-7-f7f7010520ca> in get_flash_r(mi, sigi, ti)
#      30     #print(integrand(v0/5,0,0,b_list[-3]) )
#      31     #return nquad(integrand, [[  0,vesc], [ 0,max(b_list)]],opts={'epsrel':1e-2,'epsabs':1e-12,'limit':5})
# ---> 32     rate, error = dblquad(integrand,0,max(b_list), 0,vesc,epsrel=1e-1,epsabs=1e-5)
#      33     #print(rate,error)
#      34     return rate
#
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/scipy/integrate/quadpack.py in dblquad(func, a, b, gfun, hfun, args, epsabs, epsrel)
#     579
#     580     return nquad(func, [temp_ranges, [a, b]], args=args,
# --> 581             opts={"epsabs": epsabs, "epsrel": epsrel})
#     582
#     583
#
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/scipy/integrate/quadpack.py in nquad(func, ranges, args, opts, full_output)
#     803     else:
#     804         opts = [opt if callable(opt) else _OptFunc(opt) for opt in opts]
# --> 805     return _NQuad(func, ranges, opts, full_output).integrate(*args)
#     806
#     807
#
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/scipy/integrate/quadpack.py in integrate(self, *args, **kwargs)
#     858             f = partial(self.integrate, depth=depth+1)
#     859         quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# --> 860                       **opt)
#     861         value = quad_r[0]
#     862         abserr = quad_r[1]
#
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     446     if points is None:
#     447         if infbounds == 0:
# --> 448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
#     450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/scipy/integrate/quadpack.py in integrate(self, *args, **kwargs)
#     858             f = partial(self.integrate, depth=depth+1)
#     859         quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# --> 860                       **opt)
#     861         value = quad_r[0]
#     862         abserr = quad_r[1]
#
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     446     if points is None:
#     447         if infbounds == 0:
# --> 448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
#     450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# <ipython-input-7-f7f7010520ca> in integrand(v, b)
#      26         #print(v,b)
#      27
# ---> 28         return dPhidb(v,b)*pflash_interp(b,v)*f_vDM(v)/(s2Gyr)
#      29
#      30     #print(integrand(v0/5,0,0,b_list[-3]) )
#
# <ipython-input-7-f7f7010520ca> in f_wrapped(*args, **kwargs)
#       3 def my_round(f):
#       4     def f_wrapped(*args,**kwargs):
# ----> 5         return np.around(f(*args,**kwargs),0)
#       6     return f_wrapped
#       7
#
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/scipy/interpolate/interpolate.py in __call__(self, x, y, dx, dy, assume_sorted)
#     299                                 (self.y_min, self.y_max)))
#     300
# --> 301         z = fitpack.bisplev(x, y, self.tck, dx, dy)
#     302         z = atleast_2d(z)
#     303         z = transpose(z)
#
# /sw/arcts/centos7/python3.7-anaconda/2019.07/lib/python3.7/site-packages/scipy/interpolate/_fitpack_impl.py in bisplev(x, y, tck, dx, dy)
#    1045     if (len(x.shape) != 1) or (len(y.shape) != 1):
#    1046         raise ValueError("First two entries should be rank-1 arrays.")
# -> 1047     z, ier = _fitpack._bispev(tx, ty, c, kx, ky, x, y, dx, dy)
#    1048     if ier == 10:
#    1049         raise ValueError("Invalid input data")
#
# KeyboardInterrupt:

# %%
points_flashed=np.where(flash_rates>=np.log10(0.3))
flash_rates=np.array(flash_rates)
flash_rates[points_flashed]

fig, ax = plt.subplots();

M_alltime=np.array([M for ti in range(len(t_list))])[points_flashed]
Sig_alltime=np.array([Sig for ti in range(len(t_list))])[points_flashed]
Sig_alltime2=np.array([(1/20)*Sig for ti in range(len(t_list))])[points_flashed]

scatters=[plt.scatter(M_alltime,Sig_alltime),plt.scatter(M_alltime,Sig_alltime2,c='r')]
ax.legend(scatters,["Solar Metallicity, [Z]=0","[Z]=-2"],loc=2)


ax.add_patch(matplotlib.patches.Polygon(White_Dwarf_bounds,closed=True,alpha=0.2))

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim(1e-8,1e10)
ax.set_xlim(1e10,1e23)
ax.set_ylabel(r'$\sigma_{\chi n} [cm^2]$')
ax.set_xlabel(r'$m_{\chi} [g]$')
ax.set_title(r"Rough Bound Assuming >0.3 Flashes per Stellar RG Lifetime")
# Out:
# Text(0.5, 1.0, 'Rough Bound Assuming >0.3 Flashes per Stellar RG Lifetime')
